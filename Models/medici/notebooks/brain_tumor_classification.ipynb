# %%
import keras
import tensorflow as tf
import numpy as np
from keras.src.models import Sequential
from keras.src.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, Input, LeakyReLU, GlobalAveragePooling2D, BatchNormalization,Rescaling, RandomFlip, RandomRotation,RandomBrightness
from sklearn.utils.class_weight import compute_class_weight
from keras.src.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.src.regularizers import L2
# Out:
# 2025-05-01 20:06:21.805894: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746129982.079958      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746129982.156713      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dir_original_data = "/kaggle/input/brain-tumor-mri-dataset"

train_dataset = keras.utils.image_dataset_from_directory(
    dir_original_data+"/Training",
    labels="inferred",
    label_mode='categorical',
    color_mode='grayscale',
    seed=42
)

test_dataset = keras.utils.image_dataset_from_directory(
    dir_original_data+"/Testing",
    labels="inferred",
    label_mode='categorical',
    color_mode='grayscale',
    seed=42
)
# Out:
# Found 5712 files belonging to 4 classes.
# I0000 00:00:1746129999.983477      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746129999.984432      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 1311 files belonging to 4 classes.

# %%
def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

data_augmentation = Sequential([ RandomFlip("horizontal"), RandomRotation(0.2), ])

def augment(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    image = data_augmentation(image)
    return image, label

train_dataset = train_dataset.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# %%
strategy = tf.distribute.MirroredStrategy(["GPU:0", "GPU:1"])
with strategy.scope():

    model = Sequential([ 
    
    Input(shape=(512, 512, 1)),

    Conv2D(32, (7, 7), strides=2, padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((3, 3), strides=2),
    
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    GlobalAveragePooling2D(),
    Dropout(0.5),
    
    Dense(4, activation='softmax')
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.AUC()]
    )

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 32)        │           1,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256, 256, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 127, 127, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 127, 127, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 127, 127, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 127, 127, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 63, 63, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 63, 63, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 63, 63, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 63, 63, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 63, 63, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 63, 63, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 31, 31, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 31, 31, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 31, 31, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 31, 31, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 31, 31, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 31, 31, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,168,452 (4.46 MB)
#  Trainable params: 1,166,596 (4.45 MB)
#  Non-trainable params: 1,856 (7.25 KB)

# %% [markdown]
# data_augmentation = Sequential([
#     RandomFlip("horizontal"),
#     RandomRotation(0.2),
# ])
#
#
# with strategy.scope():
#     model = Sequential([
#         Input(shape=(512, 512, 1)),
#         Rescaling(1./255),
#         data_augmentation,
#
#         Conv2D(32, (7, 7), strides=2, padding='same', activation='relu'),
#         BatchNormalization(),
#         MaxPooling2D((3, 3), strides=2),
#
#         Conv2D(64, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         Conv2D(64, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         MaxPooling2D((2, 2)),
#         Dropout(0.3),
#
#         Conv2D(128, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         Conv2D(128, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         MaxPooling2D((2, 2)),
#         Dropout(0.3),
#
#         Conv2D(256, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         Conv2D(256, (3, 3), padding='same', activation='relu'),
#         BatchNormalization(),
#         GlobalAveragePooling2D(),
#         Dropout(0.5),
#
#         Dense(4, activation='softmax')
#     ])
#
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
#         loss='categorical_crossentropy',
#         metrics=['accuracy', tf.keras.metrics.AUC()]
#     )
#
# model.summary()

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=13, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('/kaggle/working/brain_tumor_classifier.keras', save_best_only=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.25, patience=4, min_lr=1e-12)

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=test_dataset,
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# E0000 00:00:1746130012.347854      31 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_1_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1746130014.023327      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746130014.030161      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.6290 - auc: 0.8616 - loss: 0.9091 - val_accuracy: 0.2195 - val_auc: 0.5449 - val_loss: 4.3858 - learning_rate: 0.0010
# Epoch 2/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.7328 - auc: 0.9210 - loss: 0.6755 - val_accuracy: 0.3216 - val_auc: 0.5672 - val_loss: 5.3625 - learning_rate: 0.0010
# Epoch 3/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.7937 - auc: 0.9478 - loss: 0.5455 - val_accuracy: 0.5625 - val_auc: 0.8183 - val_loss: 1.4398 - learning_rate: 0.0010
# Epoch 4/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.8150 - auc: 0.9568 - loss: 0.4935 - val_accuracy: 0.6692 - val_auc: 0.8502 - val_loss: 1.2010 - learning_rate: 0.0010
# Epoch 5/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.8287 - auc: 0.9643 - loss: 0.4469 - val_accuracy: 0.7043 - val_auc: 0.8957 - val_loss: 0.8622 - learning_rate: 0.0010
# Epoch 6/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8615 - auc: 0.9712 - loss: 0.3974 - val_accuracy: 0.5625 - val_auc: 0.8278 - val_loss: 1.3980 - learning_rate: 0.0010
# Epoch 7/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.8592 - auc: 0.9762 - loss: 0.3630 - val_accuracy: 0.6037 - val_auc: 0.8647 - val_loss: 1.1460 - learning_rate: 0.0010
# Epoch 8/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.8797 - auc: 0.9805 - loss: 0.3272 - val_accuracy: 0.8095 - val_auc: 0.9536 - val_loss: 0.5263 - learning_rate: 0.0010
# Epoch 9/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.8924 - auc: 0.9843 - loss: 0.2888 - val_accuracy: 0.7470 - val_auc: 0.9313 - val_loss: 0.7957 - learning_rate: 0.0010
# Epoch 10/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.8992 - auc: 0.9850 - loss: 0.2795 - val_accuracy: 0.7607 - val_auc: 0.9345 - val_loss: 0.6513 - learning_rate: 0.0010
# Epoch 11/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9018 - auc: 0.9862 - loss: 0.2732 - val_accuracy: 0.6555 - val_auc: 0.8935 - val_loss: 1.0217 - learning_rate: 0.0010
# Epoch 12/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9132 - auc: 0.9879 - loss: 0.2472 - val_accuracy: 0.6418 - val_auc: 0.8439 - val_loss: 1.2982 - learning_rate: 0.0010
# Epoch 13/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9236 - auc: 0.9915 - loss: 0.2070 - val_accuracy: 0.9375 - val_auc: 0.9924 - val_loss: 0.1747 - learning_rate: 2.5000e-04
# Epoch 14/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9492 - auc: 0.9945 - loss: 0.1626 - val_accuracy: 0.9345 - val_auc: 0.9943 - val_loss: 0.1808 - learning_rate: 2.5000e-04
# Epoch 15/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9384 - auc: 0.9951 - loss: 0.1631 - val_accuracy: 0.9543 - val_auc: 0.9971 - val_loss: 0.1234 - learning_rate: 2.5000e-04
# Epoch 16/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.9468 - auc: 0.9941 - loss: 0.1642 - val_accuracy: 0.9360 - val_auc: 0.9930 - val_loss: 0.1781 - learning_rate: 2.5000e-04
# Epoch 17/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9415 - auc: 0.9943 - loss: 0.1626 - val_accuracy: 0.9329 - val_auc: 0.9930 - val_loss: 0.1877 - learning_rate: 2.5000e-04
# Epoch 18/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9472 - auc: 0.9946 - loss: 0.1543 - val_accuracy: 0.9497 - val_auc: 0.9924 - val_loss: 0.1581 - learning_rate: 2.5000e-04
# Epoch 19/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9521 - auc: 0.9963 - loss: 0.1364 - val_accuracy: 0.9451 - val_auc: 0.9941 - val_loss: 0.1579 - learning_rate: 2.5000e-04
# Epoch 20/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.9523 - auc: 0.9963 - loss: 0.1342 - val_accuracy: 0.9665 - val_auc: 0.9986 - val_loss: 0.0886 - learning_rate: 6.2500e-05
# Epoch 21/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9613 - auc: 0.9973 - loss: 0.1162 - val_accuracy: 0.9741 - val_auc: 0.9990 - val_loss: 0.0807 - learning_rate: 6.2500e-05
# Epoch 22/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9610 - auc: 0.9972 - loss: 0.1158 - val_accuracy: 0.9710 - val_auc: 0.9985 - val_loss: 0.0881 - learning_rate: 6.2500e-05
# Epoch 23/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9669 - auc: 0.9975 - loss: 0.1066 - val_accuracy: 0.9588 - val_auc: 0.9976 - val_loss: 0.1102 - learning_rate: 6.2500e-05
# Epoch 24/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.9614 - auc: 0.9978 - loss: 0.1051 - val_accuracy: 0.9787 - val_auc: 0.9990 - val_loss: 0.0768 - learning_rate: 6.2500e-05
# Epoch 25/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9606 - auc: 0.9972 - loss: 0.1171 - val_accuracy: 0.9756 - val_auc: 0.9990 - val_loss: 0.0741 - learning_rate: 6.2500e-05
# Epoch 26/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9585 - auc: 0.9975 - loss: 0.1152 - val_accuracy: 0.9756 - val_auc: 0.9991 - val_loss: 0.0727 - learning_rate: 6.2500e-05
# Epoch 27/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9603 - auc: 0.9975 - loss: 0.1114 - val_accuracy: 0.9787 - val_auc: 0.9991 - val_loss: 0.0736 - learning_rate: 6.2500e-05
# Epoch 28/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9631 - auc: 0.9976 - loss: 0.1046 - val_accuracy: 0.9848 - val_auc: 0.9992 - val_loss: 0.0616 - learning_rate: 6.2500e-05
# Epoch 29/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9629 - auc: 0.9978 - loss: 0.1058 - val_accuracy: 0.9863 - val_auc: 0.9991 - val_loss: 0.0628 - learning_rate: 6.2500e-05
# Epoch 30/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9688 - auc: 0.9985 - loss: 0.0867 - val_accuracy: 0.9665 - val_auc: 0.9984 - val_loss: 0.0923 - learning_rate: 6.2500e-05
# Epoch 31/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9678 - auc: 0.9974 - loss: 0.0999 - val_accuracy: 0.9741 - val_auc: 0.9990 - val_loss: 0.0709 - learning_rate: 6.2500e-05
# Epoch 32/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9647 - auc: 0.9982 - loss: 0.0968 - val_accuracy: 0.9802 - val_auc: 0.9990 - val_loss: 0.0744 - learning_rate: 6.2500e-05
# Epoch 33/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9672 - auc: 0.9980 - loss: 0.0936 - val_accuracy: 0.9802 - val_auc: 0.9990 - val_loss: 0.0694 - learning_rate: 1.5625e-05
# Epoch 34/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9673 - auc: 0.9979 - loss: 0.0991 - val_accuracy: 0.9741 - val_auc: 0.9991 - val_loss: 0.0737 - learning_rate: 1.5625e-05
# Epoch 35/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9672 - auc: 0.9975 - loss: 0.0984 - val_accuracy: 0.9802 - val_auc: 0.9992 - val_loss: 0.0679 - learning_rate: 1.5625e-05
# Epoch 36/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9679 - auc: 0.9977 - loss: 0.0997 - val_accuracy: 0.9771 - val_auc: 0.9991 - val_loss: 0.0736 - learning_rate: 1.5625e-05
# Epoch 37/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9713 - auc: 0.9987 - loss: 0.0824 - val_accuracy: 0.9771 - val_auc: 0.9992 - val_loss: 0.0620 - learning_rate: 3.9063e-06
# Epoch 38/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9704 - auc: 0.9984 - loss: 0.0893 - val_accuracy: 0.9741 - val_auc: 0.9988 - val_loss: 0.0786 - learning_rate: 3.9063e-06
# Epoch 39/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9660 - auc: 0.9979 - loss: 0.1018 - val_accuracy: 0.9802 - val_auc: 0.9988 - val_loss: 0.0756 - learning_rate: 3.9063e-06
# Epoch 40/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9704 - auc: 0.9978 - loss: 0.0912 - val_accuracy: 0.9771 - val_auc: 0.9993 - val_loss: 0.0658 - learning_rate: 3.9063e-06
# Epoch 41/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9678 - auc: 0.9981 - loss: 0.0963 - val_accuracy: 0.9878 - val_auc: 0.9994 - val_loss: 0.0556 - learning_rate: 9.7656e-07
# Epoch 42/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9686 - auc: 0.9980 - loss: 0.0968 - val_accuracy: 0.9802 - val_auc: 0.9990 - val_loss: 0.0716 - learning_rate: 9.7656e-07
# Epoch 43/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9725 - auc: 0.9985 - loss: 0.0864 - val_accuracy: 0.9787 - val_auc: 0.9989 - val_loss: 0.0720 - learning_rate: 9.7656e-07
# Epoch 44/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9677 - auc: 0.9978 - loss: 0.0944 - val_accuracy: 0.9848 - val_auc: 0.9996 - val_loss: 0.0513 - learning_rate: 9.7656e-07
# Epoch 45/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9709 - auc: 0.9982 - loss: 0.0919 - val_accuracy: 0.9802 - val_auc: 0.9996 - val_loss: 0.0535 - learning_rate: 9.7656e-07
# Epoch 46/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9689 - auc: 0.9986 - loss: 0.0863 - val_accuracy: 0.9848 - val_auc: 0.9996 - val_loss: 0.0515 - learning_rate: 9.7656e-07
# Epoch 47/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9724 - auc: 0.9980 - loss: 0.0933 - val_accuracy: 0.9863 - val_auc: 0.9995 - val_loss: 0.0560 - learning_rate: 9.7656e-07
# Epoch 48/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.9715 - auc: 0.9986 - loss: 0.0826 - val_accuracy: 0.9817 - val_auc: 0.9991 - val_loss: 0.0673 - learning_rate: 9.7656e-07
# Epoch 49/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9682 - auc: 0.9984 - loss: 0.0886 - val_accuracy: 0.9848 - val_auc: 0.9992 - val_loss: 0.0662 - learning_rate: 2.4414e-07
# Epoch 50/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 84ms/step - accuracy: 0.9730 - auc: 0.9985 - loss: 0.0858 - val_accuracy: 0.9802 - val_auc: 0.9989 - val_loss: 0.0734 - learning_rate: 2.4414e-07
# Epoch 51/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9716 - auc: 0.9984 - loss: 0.0861 - val_accuracy: 0.9893 - val_auc: 0.9995 - val_loss: 0.0498 - learning_rate: 2.4414e-07
# Epoch 52/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.9632 - auc: 0.9976 - loss: 0.1063 - val_accuracy: 0.9787 - val_auc: 0.9992 - val_loss: 0.0681 - learning_rate: 2.4414e-07
# Epoch 53/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.9729 - auc: 0.9984 - loss: 0.0849 - val_accuracy: 0.9771 - val_auc: 0.9988 - val_loss: 0.0778 - learning_rate: 2.4414e-07
# Epoch 54/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 83ms/step - accuracy: 0.9700 - auc: 0.9983 - loss: 0.0856 - val_accuracy: 0.9802 - val_auc: 0.9995 - val_loss: 0.0555 - learning_rate: 2.4414e-07
# Epoch 55/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 80ms/step - accuracy: 0.9686 - auc: 0.9980 - loss: 0.0899 - val_accuracy: 0.9863 - val_auc: 0.9995 - val_loss: 0.0517 - learning_rate: 2.4414e-07
# Epoch 56/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9706 - auc: 0.9984 - loss: 0.0873 - val_accuracy: 0.9787 - val_auc: 0.9993 - val_loss: 0.0644 - learning_rate: 6.1035e-08
# Epoch 57/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 82ms/step - accuracy: 0.9750 - auc: 0.9982 - loss: 0.0887 - val_accuracy: 0.9802 - val_auc: 0.9995 - val_loss: 0.0582 - learning_rate: 6.1035e-08
# Epoch 58/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9730 - auc: 0.9986 - loss: 0.0848 - val_accuracy: 0.9787 - val_auc: 0.9993 - val_loss: 0.0642 - learning_rate: 6.1035e-08
# Epoch 59/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9629 - auc: 0.9976 - loss: 0.1074 - val_accuracy: 0.9863 - val_auc: 0.9993 - val_loss: 0.0590 - learning_rate: 6.1035e-08
# Epoch 60/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9735 - auc: 0.9980 - loss: 0.0869 - val_accuracy: 0.9802 - val_auc: 0.9990 - val_loss: 0.0703 - learning_rate: 1.5259e-08
# Epoch 61/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - accuracy: 0.9702 - auc: 0.9985 - loss: 0.0888 - val_accuracy: 0.9878 - val_auc: 0.9996 - val_loss: 0.0507 - learning_rate: 1.5259e-08
# Epoch 62/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step - accuracy: 0.9698 - auc: 0.9985 - loss: 0.0872 - val_accuracy: 0.9832 - val_auc: 0.9994 - val_loss: 0.0561 - learning_rate: 1.5259e-08
# Epoch 63/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.9729 - auc: 0.9986 - loss: 0.0815 - val_accuracy: 0.9863 - val_auc: 0.9993 - val_loss: 0.0591 - learning_rate: 1.5259e-08
# Epoch 64/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - accuracy: 0.9736 - auc: 0.9986 - loss: 0.0839 - val_accuracy: 0.9878 - val_auc: 0.9994 - val_loss: 0.0543 - learning_rate: 3.8147e-09

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

model_path = "/kaggle/working/brain_tumor_classifier.keras"

model = keras.models.load_model(model_path)
model.summary()

predictions = []
real_labels = []

for images, labels in test_dataset:
    preds = model.predict(images)
    predictions.extend(np.argmax(preds, axis=1)) 
    real_labels.extend(np.argmax(labels.numpy(), axis=1)) 

cm = confusion_matrix(real_labels, predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(4), yticklabels=range(4))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

accuracy = accuracy_score(real_labels, predictions)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 32)        │           1,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256, 256, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 127, 127, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 127, 127, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 127, 127, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 127, 127, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 63, 63, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 63, 63, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 63, 63, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 63, 63, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 63, 63, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 63, 63, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 31, 31, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 31, 31, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 31, 31, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 31, 31, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 31, 31, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 31, 31, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,501,646 (13.36 MB)
#  Trainable params: 1,166,596 (4.45 MB)
#  Non-trainable params: 1,856 (7.25 KB)
#  Optimizer params: 2,333,194 (8.90 MB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# Accuracy: 98.40%
